# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

pd.set_option('max_column', 100)

# %%
raw_path = '../../dataset/raw/'
mst_path = '../../dataset/mst/'
fig_path = '../../export/01_summary_stats_ebike/'

# %%
os.listdir(mst_path)
# Out:
# ['Participant_Survey.csv', 'question_lookup.csv']

# %%
#load in clean data
df = pd.read_csv(mst_path+"Participant_Survey.csv")
df.head()
# Out:
#    respondent_id  collector_id           start_date             end_date  \
# 0            NaN           NaN                  NaN                  NaN
# 1   6.949403e+09   169864446.0  2018-10-15 10:08:23  2018-10-15 10:13:24
# 2   6.949103e+09   169864446.0  2018-10-14 10:45:19  2018-10-14 10:56:45
# 3   6.948039e+09   169864446.0  2018-10-10 13:29:17  2018-10-10 14:06:31
# 4   6.947148e+09   169864446.0  2018-10-08 08:17:19  2018-10-08 08:22:06
#
#         ip_address  email_address  first_name  last_name  custom_data_1  \
# 0              NaN            NaN         NaN        NaN            NaN
# 1       12.9.23.93            NaN         NaN        NaN            NaN
# 2   174.210.16.167            NaN         NaN        NaN            NaN
# 3  104.129.198.126            NaN         NaN        NaN            NaN
# 4     97.90.130.11            NaN         NaN        NaN            NaN
#
#   what_brand/type_of_e-bike_did_you_buy_(e.g.,_sonders_x)?  \
# 0                                Open-Ended Response
# 1                                            Haibike
# 2                                              Yuba
# 3  Vilano  https://www.amazon.com/gp/product/B071...
# 4                              Diamondback Trace EXC
#
#   how_much_did_your_e-bike_cost_(before_the_rebate)?  \
# 0                                           Response
# 1                                    $2,001 - $2,500
# 2                                     $2,500 or more
# 3                                     $1,000 or less
# 4                                    $1,001 - $1,500
#
#   overall,_how_satisfied_are_you_with_your_e-bike?  \
# 0                                         Response
# 1                              Extremely satisfied
# 2                              Extremely satisfied
# 3                               Somewhat satisfied
# 4                              Extremely satisfied
#
#   why_do_you_like_or_dislike_your_e-bike?_what,_if_any,_other_thoughts_would_you_like_to_share_about_your_e-bike?  \
# 0                                Open-Ended Response
# 1  My e-bike allows me to keep up with others and...
# 2  It’s enabled my wife and I to have just one ca...
# 3  My particular e-bike is an assist model only. ...
# 4                         Heavy & tires seem fragile
#
#   how_much_did_the_$700_rebate_influence_your_decision_to_purchase_an_e-bike?  \
# 0                                           Response
# 1                                              A lot
# 2                                           Somewhat
# 3                                              A lot
# 4                                              A lot
#
#   how_far_is_your_average_trip_by_e-bike?  \
# 0                                Response
# 1                              8-10 miles
# 2                               3-4 miles
# 3                        10 or more miles
# 4                               0-2 miles
#
#   for_what_purpose_aremost_of_your_e-bike_rides?  business/work_use  \
# 0                                       Response  Business/Work Use
# 1                           Recreation / Leisure  Business/Work Use
# 2     Transportation (short trips, errands, etc)  Business/Work Use
# 3                           Recreation / Leisure                NaN
# 4                        Commuting (work/school)  Business/Work Use
#
#    injury_or_disability  sustainability_/_environmental_benefits  \
# 0  Injury or Disability  Sustainability / Environmental Benefits
# 1                   NaN  Sustainability / Environmental Benefits
# 2                   NaN                                      NaN
# 3                   NaN  Sustainability / Environmental Benefits
# 4                   NaN  Sustainability / Environmental Benefits
#
#    cargo_hauling  recreation_or_exercise  transport_children  \
# 0  Cargo Hauling  Recreation or Exercise  Transport children
# 1            NaN  Recreation or Exercise                 NaN
# 2  Cargo Hauling  Recreation or Exercise                 NaN
# 3            NaN                     NaN                 NaN
# 4            NaN  Recreation or Exercise                 NaN
#
#     save_money_/_reducetransportation_costs  hills  \
# 0  Save money / reduce transportation costs  Hills
# 1                                       NaN  Hills
# 2  Save money / reduce transportation costs  Hills
# 3  Save money / reduce transportation costs    NaN
# 4  Save money / reduce transportation costs    NaN
#
#                               other_(please_specify)  \
# 0                             Other (please specify)
# 1                                                NaN
# 2                                                NaN
# 3  Because the Rebate was available and I was eli...
# 4                                                NaN
#
#    social_media_(e.g.,_facebook,_instagram,_twitter)  news_article  \
# 0  Social Media (e.g., Facebook, Instagram, Twitter)  News article
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#    bikesgv_listserve/email  friend/family/colleague  flyer  poster  \
# 0  BikeSGV listserve/email  Friend/family/colleague  Flyer  Poster
# 1  BikeSGV listserve/email                      NaN    NaN     NaN
# 2                      NaN                      NaN    NaN     NaN
# 3                      NaN                      NaN    NaN     NaN
# 4                      NaN  Friend/family/colleague    NaN     NaN
#
#                             other_(please_specify).1  \
# 0                             Other (please specify)
# 1                                                NaN
# 2                                        Salesperson
# 3  I just happened to check the BikeSGV page and ...
# 4                                                NaN
#
#   how_familiar_were_you_with_e-bikes_before_hearing_about_this_rebate_program?  \
# 0                                           Response
# 1                                  Somewhat familiar
# 2                                Somewhat unfamiliar
# 3                                    Very unfamiliar
# 4                                    Very unfamiliar
#
#    bicycle_(regular)  electric_bicycle_(e-bike)  working_motor_vehicle  \
# 0  Bicycle (regular)  Electric Bicycle (E-bike)  Working motor vehicle
# 1                NaN  Electric Bicycle (E-bike)  Working motor vehicle
# 2                NaN  Electric Bicycle (E-bike)  Working motor vehicle
# 3  Bicycle (regular)  Electric Bicycle (E-bike)  Working motor vehicle
# 4                NaN  Electric Bicycle (E-bike)  Working motor vehicle
#
#    scooter  motorcycle  none_of_the_above  walked  biked  skated_/_scooted  \
# 0  Scooter  Motorcycle  None of the above  Walked  Biked  Skated / Scooted
# 1  Scooter         NaN                NaN  Walked    NaN               NaN
# 2      NaN         NaN                NaN  Walked    NaN               NaN
# 3  Scooter         NaN                NaN     NaN  Biked  Skated / Scooted
# 4      NaN         NaN                NaN     NaN    NaN               NaN
#
#    used_public_transit  carpooled_/_rode_as_a_passenger  \
# 0  Used public transit  Carpooled / rode as a passenger
# 1  Used public transit                              NaN
# 2  Used public transit                              NaN
# 3                  NaN                              NaN
# 4                  NaN  Carpooled / rode as a passenger
#
#    used_ride_share_service_(lyft/uber)  drove_car_/_motorcycle walked.1  \
# 0  Used ride share service (Lyft/Uber)  Drove car / motorcycle   Walked
# 1                                  NaN  Drove car / motorcycle      NaN
# 2                                  NaN  Drove car / motorcycle   Walked
# 3                                  NaN  Drove car / motorcycle      NaN
# 4  Used ride share service (Lyft/Uber)  Drove car / motorcycle      NaN
#
#   biked.1 skated_/_scooted.1 used_public_transit.1  \
# 0   Biked   Skated / Scooted   Used public transit
# 1   Biked                NaN   Used public transit
# 2   Biked                NaN                   NaN
# 3   Biked   Skated / Scooted                   NaN
# 4     NaN                NaN                   NaN
#
#   carpooled_/_rode_as_a_passenger.1 used_ride_share_service_(lyft/uber).1  \
# 0   Carpooled / rode as a passenger   Used ride share service (Lyft/Uber)
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4   Carpooled / rode as a passenger   Used ride share service (Lyft/Uber)
#
#   drove_car_/_motorcycle.1  \
# 0   Drove car / motorcycle
# 1   Drove car / motorcycle
# 2   Drove car / motorcycle
# 3   Drove car / motorcycle
# 4   Drove car / motorcycle
#
#   how_oftendid_you_bicycle_for_any_purposebefore_purchasing_an_e-bike?  \
# 0                                           Response
# 1                                  1-11 times a year
# 2                                  1-11 times a year
# 3                                    1-2 days a week
# 4                                              Never
#
#   how_often_do_you_bicyclefor_any_purposesince_purchasing_an_e-bike?  \
# 0                                           Response
# 1                                    1-2 days a week
# 2                                  1-3 times a month
# 3                                    1-2 days a week
# 4                                  1-11 times a year
#
#   do_you_use_your_e-bike_for_some_trips_that_you_used_to_take_by_car?  \
# 0                                           Response
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   have_youused_your_e-bikeon_a_river_path_or_‘greenway’_in_the_past_12_months?_(e.g.,_san_gabriel_river_or_rio_hondo_river_trails)  \
# 0                                           Response
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#   how_easy_or_difficult_is_it_to_bicycle_in_your_community?  \
# 0                                           Response
# 1                                      Somewhat easy
# 2                                                NaN
# 3                                            Neither
# 4                                                NaN
#
#   did_your_level_of_comfort_riding_a_bicycle_in_traffic_increase_after_taking_the_city_cycling_class?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                NaN
#
#    off-street_greenways_/_multi-use_paths  \
# 0  Off-street greenways / multi-use paths
# 1                           Somewhat safe
# 2                                     NaN
# 3                               Very safe
# 4                                     NaN
#
#   on-street_separated_/_physically_‘protected’_bikeways  buffered_bike_lanes  \
# 0  On-street separated / physically ‘protected’ b...     Buffered bike lanes
# 1                                      Somewhat safe           Somewhat safe
# 2                                                NaN                     NaN
# 3                                        Very unsafe           Somewhat safe
# 4                                                NaN                     NaN
#
#    color_painted_bike_lanes  striped_bike_lanes  \
# 0  Color painted bike lanes  Striped bike lanes
# 1             Somewhat safe       Somewhat safe
# 2                       NaN                 NaN
# 3             Somewhat safe       Somewhat safe
# 4                       NaN                 NaN
#
#    bike_routes_(signage,_sharrows)  \
# 0  Bike routes (signage, sharrows)
# 1                    Somewhat safe
# 2                              NaN
# 3                    Somewhat safe
# 4                              NaN
#
#   how_safe_doyou_feel_riding_a_bicycle_in_traffic?  \
# 0                                         Response
# 1                                    Somewhat safe
# 2                                              NaN
# 3                                    Somewhat safe
# 4                                              NaN
#
#   what_barriers_to_using_your_e-bike_have_you_encountered_thus_far,_if_any?  \
# 0                                Open-Ended Response
# 1  It's a little heavy. So it is hard for me to c...
# 2                                                NaN
# 3                       Weight.  Parking.  Charging.
# 4                                                NaN
#
#   how_many_members_of_your_household_use_your_e-bike_at_least_once_a_month?  \
# 0                                           Response
# 1                                                  0
# 2                                                NaN
# 3                                                  1
# 4                                                NaN
#
#    response other_(please_specify).2  \
# 0  Response   Other (please specify)
# 1         1                      NaN
# 2       NaN                      NaN
# 3         2                      NaN
# 4       NaN                      NaN
#
#   would_you_like_to_see_future_e-bike_rebate_programs?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#   should_future_programsexpand_the_list_of_eligible_light_electric_vehicles_to_include_electric-scooters_and_similar_micro-mobility_devices?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                Yes
# 4                                                NaN
#
#   other_suggestions,_feedback,_or_comments_forproject_organizers.  \
# 0                                Open-Ended Response
# 1  The rebate process was slow and communication ...
# 2                                                NaN
# 3  I wanted to share my opinion of the segregated...
# 4                                                NaN
#
#   community_of_residence             zip_code number_of_persons_in_household  \
# 0    Open-Ended Response  Open-Ended Response                       Response
# 1               el Monte                91731                              2
# 2                    NaN                  NaN                            NaN
# 3           San Gabriel                 91776                      4 or more
# 4               Alhambra                91801                              3
#
#     household_income what_is_your_age_group?  electric_car  \
# 0           Response                Response  Electric Car
# 1    $75,000-$99,999                 36 - 45           NaN
# 2                NaN                     NaN           NaN
# 3  $100,000-$149,500                 46 - 55           NaN
# 4  $150,000-$199,999                 26 - 35           NaN
#
#    electric_motorcycle  electric_scooter  electric_skateboard  electric_wheel  \
# 0  Electric Motorcycle  Electric Scooter  Electric Skateboard  Electric Wheel
# 1                  NaN               NaN                  NaN             NaN
# 2                  NaN               NaN                  NaN             NaN
# 3                  NaN               NaN                  NaN             NaN
# 4                  NaN               NaN                  NaN             NaN
#
#    no,_i_do_not_own_other_evs  \
# 0  NO, I do not own other EVs
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  NO, I do not own other EVs
#
#                             other_(please_specify).3  \
# 0                             Other (please specify)
# 1                                                NaN
# 2                                                NaN
# 3  Own an electric scooter, but is currently out-...
# 4                                                NaN
#
#    american_indian_or_alaska_native  asian/pacific_islander  \
# 0  American Indian or Alaska Native  Asian/Pacific Islander
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN  Asian/Pacific Islander
# 4                               NaN  Asian/Pacific Islander
#
#    black_or_african_american  hispanic_or_latino  white  multi-ethnic  \
# 0  Black or African American  Hispanic or Latino  White  Multi-ethnic
# 1                        NaN  Hispanic or Latino    NaN           NaN
# 2                        NaN                 NaN    NaN           NaN
# 3                        NaN                 NaN    NaN           NaN
# 4                        NaN                 NaN    NaN           NaN
#
#    decline_to_state other_(please_specify).4  female  male decline_to_state.1  \
# 0  Decline to state   Other (please specify)  Female  Male   Decline to state
# 1               NaN                      NaN  Female   NaN                NaN
# 2               NaN                      NaN     NaN   NaN                NaN
# 3               NaN                      NaN     NaN  Male                NaN
# 4               NaN                      NaN     NaN  Male                NaN
#
#    other
# 0  Other
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
#convert column 12 & 13 to lists
satisfaction_response = df["overall,_how_satisfied_are_you_with_your_e-bike?"].tolist()[1:]
print(satisfaction_response)

satisfaction_comments = df["why_do_you_like_or_dislike_your_e-bike?_what,_if_any,_other_thoughts_would_you_like_to_share_about_your_e-bike?"].tolist()[1:]
print(satisfaction_comments)
# Out:
# ['Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely\xa0dissatisfied', 'Somewhat satisfied', 'Extremely\xa0dissatisfied', 'Neither satisfied nor dissatisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Extremely satisfied', 'Somewhat satisfied', 'Extremely satisfied', 'Somewhat satisfied']
# ['My e-bike allows me to keep up with others and do hills easily.', 'It’s enabled my wife and I to have just one car (gave our other car to our daughter). My wife uses it to commute, I work at home).Salesperdon', 'My particular e-bike is an assist model only.  Which is fine, you could theoretically put it in a low gear and pretend to pedal and it would scoot you along.  Wish it had a trigger throttle though.  The model is also a lot heavier, but all E-Bikes are heavy.  I also wish it had more gear selections, but it was one of the "few" that were in stock at the time I was shopping for one.  I had other choices in mind, but were out-of-stock throughout the time limit I had available to me.', 'Heavy & tires seem fragile', 'I purchased a Sondors Fold X7 bike with fat tires. At 64 lb., it was quite heavy. I could take it on Metro Rail and Metrolink, but not on buses or Amtrak. I had to adjust the brakes a lot and after 2200 mi., I needed to replace the brake pads. after that I worked from time to time to get them adjusted properly. I purchased a Sondors Fold Mini intending to sell the original bike after the year was up. I had hopes that the Mini would be able to fit on a bus rack, but the tires were too wide (2.5") to fit in a bus rack. I replace them with narrower tires only to discover that the bus arm wouldn\'t retract enough to hold the bike securely. I think now that the bike might have been able to have been held if the arm was placed on the top tube of the frame or if i installed a front rack but I never had a chance to test this because both bikes were stolen from my residence at the end of the Labor Day weekend, The Fold X7 had a more than adequate range, but the because of its weight the bike was somewhat unwieldly. A month or so ago I visited the Azusa Costco and found that they sell e-bikes on annual roadshows. They had two Gen-Ze models. I think that one of these would have better fit my needs if I got one with a step-through frame. There is something wrong with my left leg and it makes it difficult for me to stand on it and lift right leg to mount the bike unless I hold onto something. Otherwise I need to lean the bike over a bit to get my leg over it.', 'The tires are too thick.', 'makes me want to get out and go for a ride. if im not working i ride every day. ', 'No throttle, heavy', "I can travel more than 20 miles, and it's folding ebike so it's easier to carry to gold line. The cadence sensor only has 6 magnets, so it's not as smooth as more expensive model. ", "The frame is a large frame with no option for a medium. Shorter people will have issue with straddling it, like I do. The 2nd thing I noticed is there doesn't feel any difference between each of the power settings. I contacted the company and they said you would notice it on hills. I still don't feel any difference, only one power setting. I have ridden other e-bikes and can definitely feel the difference when going through each of the power assist levels.", "love riding the bike.  it shifts well and makes it easy to get extra exercise.  Only concern I have is when I have to lock the bike up outside when I'm inside for a while.  I'm concerned that it will be stolen because it's a expensive great bike.", 'Needed a road bike and the Ebike really helps with riding a long distance.', 'Strong motor, big fat tires.', nan, 'The E-bike is quite heavy and would be difficult to ride without the electrical assist. ', 'I am 60 years old and it put me back on a bike again I know Venture all over the community and local hillsides enjoying my exercise and touring as I did when I was 30 years old.', 'Very easy to maintain, excellent performance, long lasting battery.', "It's a bit larger than I would have like.  They're a great alternative to vehicles for shorter trips.", "Technical Support was lacking for this bike.  If i didn't have the ability to do my own repairs it would be very difficult to keep the bike functional.", 'I love the ease of use, the alternative to  ...

# %%
#grouping the comments into different lists depending on the response

#lists of indices
exsat_i = [i for i, j in enumerate(satisfaction_response) if j == 'Extremely satisfied']
somsat_i = [i for i, j in enumerate(satisfaction_response) if j == 'Somewhat satisfied']
exdis_i = [i for i, j in enumerate(satisfaction_response) if j == 'Extremely\xa0dissatisfied']
neu_i = [i for i, j in enumerate(satisfaction_response) if j == 'Neither satisfied nor dissatisfied']

#print(exsat_i)
#print(somsat_i)
#print(exdis_i)
#print(neu_i)

#grouping the comments 

exsat_comments = []
somsat_comments = []
exdis_comments = []
neu_comments = []

for i in exsat_i:
    exsat_comments.append(satisfaction_comments[i])

for i in somsat_i:
    somsat_comments.append(satisfaction_comments[i])
    
for i in exdis_i:
    exdis_comments.append(satisfaction_comments[i])

for i in neu_i:
    neu_comments.append(satisfaction_comments[i])
    
print(exsat_comments)
#print(somsat_comments)
#print(exdis_comments)
#print(neu_comments)
# Out:
# ['My particular e-bike is an assist model only.  Which is fine, you could theoretically put it in a low gear and pretend to pedal and it would scoot you along.  Wish it had a trigger throttle though.  The model is also a lot heavier, but all E-Bikes are heavy.  I also wish it had more gear selections, but it was one of the "few" that were in stock at the time I was shopping for one.  I had other choices in mind, but were out-of-stock throughout the time limit I had available to me.', 'The tires are too thick.', "The frame is a large frame with no option for a medium. Shorter people will have issue with straddling it, like I do. The 2nd thing I noticed is there doesn't feel any difference between each of the power settings. I contacted the company and they said you would notice it on hills. I still don't feel any difference, only one power setting. I have ridden other e-bikes and can definitely feel the difference when going through each of the power assist levels.", nan, 'The E-bike is quite heavy and would be difficult to ride without the electrical assist. ', "Technical Support was lacking for this bike.  If i didn't have the ability to do my own repairs it would be very difficult to keep the bike functional.", 'Love the ebike for mobility to go further and commute for errands without needing to drive and park. More useful at work were parking is very expensive or not existent during lunch hours. ', 'Very heavy bike and I had a bad spill going over some finger of sand at the strand by the beach.  Tires are fat and supposed to be able to handle the sandy path.  Other than that good features.', 'Not using it as much as I should. A lot heavier than I anticipated.', 'Use it to commute to work and saves me alot of money. My only dislike is my ebike has no throttle which would be nice kn my way to work, so inwont break a sweat. Also would help me get off the line at a dead stop with traffic.']

# %%
#import nltk
#nltk.download()

# %%
#tokenizing the lists of strings

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+') #remove punctuations

exsat_comments_tok = []
somsat_comments_tok = []
exdis_comments_tok = []
neu_comments_tok = []

for comment in exsat_comments:
    comment_tok = tokenizer.tokenize(comment)
    for word in comment_tok:
        exsat_comments_tok.append(word)
        
for comment in somsat_comments:
    if pd.isnull(comment): #skip over instance where the list is empty; there is no comment
        continue
    else:
        #print(comment)
        comment_tok = tokenizer.tokenize(comment)
        #print(comment_tok)
        for word in comment_tok:
            somsat_comments_tok.append(word)

for comment in exdis_comments:
    if pd.isnull(comment): 
        continue
    else:
        #print(comment)
        comment_tok = tokenizer.tokenize(comment)
        #print(comment_tok)
        for word in comment_tok:
            exdis_comments_tok.append(word)

for comment in neu_comments:
    if pd.isnull(comment):
        continue
    else:
        #print(comment)
        comment_tok = tokenizer.tokenize(comment)
        #print(comment_tok)
        for word in comment_tok:
            neu_comments_tok.append(word)    

print(neu_comments_tok)
# Out:
# ['My', 'e', 'bike', 'allows', 'me', 'to', 'keep', 'up', 'with', 'others', 'and', 'do', 'hills', 'easily', 'It', 's', 'enabled', 'my', 'wife', 'and', 'I', 'to', 'have', 'just', 'one', 'car', 'gave', 'our', 'other', 'car', 'to', 'our', 'daughter', 'My', 'wife', 'uses', 'it', 'to', 'commute', 'I', 'work', 'at', 'home', 'Salesperdon', 'Heavy', 'tires', 'seem', 'fragile', 'I', 'can', 'travel', 'more', 'than', '20', 'miles', 'and', 'it', 's', 'folding', 'ebike', 'so', 'it', 's', 'easier', 'to', 'carry', 'to', 'gold', 'line', 'The', 'cadence', 'sensor', 'only', 'has', '6', 'magnets', 'so', 'it', 's', 'not', 'as', 'smooth', 'as', 'more', 'expensive', 'model', 'love', 'riding', 'the', 'bike', 'it', 'shifts', 'well', 'and', 'makes', 'it', 'easy', 'to', 'get', 'extra', 'exercise', 'Only', 'concern', 'I', 'have', 'is', 'when', 'I', 'have', 'to', 'lock', 'the', 'bike', 'up', 'outside', 'when', 'I', 'm', 'inside', 'for', 'a', 'while', 'I', 'm', 'concerned', 'that', 'it', 'will', 'be', 'stolen', 'because', 'it', 's', 'a', 'expensive', 'great', 'bike', 'Needed', 'a', 'road', 'bike', 'and', 'the', 'Ebike', 'really', 'helps', 'with', 'riding', 'a', 'long', 'distance', 'Strong', 'motor', 'big', 'fat', 'tires', 'I', 'am', '60', 'years', 'old', 'and', 'it', 'put', 'me', 'back', 'on', 'a', 'bike', 'again', 'I', 'know', 'Venture', 'all', 'over', 'the', 'community', 'and', 'local', 'hillsides', 'enjoying', 'my', 'exercise', 'and', 'touring', 'as', 'I', 'did', 'when', 'I', 'was', '30', 'years', 'old', 'Very', 'easy', 'to', 'maintain', 'excellent', 'performance', 'long', 'lasting', 'battery', 'It', 's', 'a', 'bit', 'larger', 'than', 'I', 'would', 'have', 'like', 'They', 're', 'a', 'great', 'alternative', 'to', 'vehicles', 'for', 'shorter', 'trips', 'I', 'love', 'the', 'ease', 'of', 'use', 'the', 'alternative', 'to', 'driving', 'the', 'environmental', 'sustainable', 'aspect', 'and', 'the', 'fact', 'that', 'it', 'can', 'still', 'function', 'as', 'a', 'regular', 'bike', 'with', 'the', 'motor', 'turned', 'off', 'Overall', 'it', 's', 'been', 'great', '80', 'mile', 'range', '28mph', 'top', 'speed', 'Suspension', 'fork', 'I', 'wish', 'the', 'manufacturer', 'offered', 'upgraded', 'tire', 'options', 'i', 'e', 'Schwalbe', 'instead', 'of', 'Kenda', 'but', 'that', 's', 'a', 'trivial', 'issue', 'Overall', 'the', 'bike', 's', 'been', 'a', 'great', 'value', 'Great', 'range', 'excellent', 'speed', 'Bad', 'Weight', 'more', 'than', 'double', 'current', 'bike', 'Cost', 'is', 'a', 'lot', 'more', 'I', 'like', 'that', 'the', 'motor', 'is', 'silent', 'and', 'my', 'bike', 'weighs', 'less', 'than', '50', 'pounds', 'I', 'like', 'that', 'there', 'is', 'a', 'throttle', 'button', 'in', 'case', 'I', 'need', 'it', 'This', 'bike', 'works', 'using', 'a', 'torque', 'assist', 'motor', 'so', 'it', 'feels', 'just', 'like', 'normal', 'pedaling', 'except', 'keeping', 'up', 'with', 'fast', 'bikers', 'is', 'now', 'easy', 'I', 'recommend', 'to', 'everyone', 'this', 'bike', 'Heavy', 'am', 'a', 'small', 'person', 'Makes', 'the', 'commute', 'to', 'work', 'so', 'much', 'easier', 'I', 'like', 'my', 'eBike', 'because', 'instead', 'of', 'getting', 'in', 'my', 'car', 'for', 'short', 'trips', 'I', 'can', 'get', 'on', 'my', 'bike', 'and', 'save', 'gas', 'and', 'time', 'Time', 'looking', 'for', 'parking', 'and', 'stuck', 'in', 'trafffic']
# ['No', 'throttle', 'heavy']

# %%
#sentiment analysis

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

sen = ['good','bad','awesome']

summary_exsat = {"positive":0,"neutral":0,"negative":0}

for word in exsat_comments_tok: 
    ss = sid.polarity_scores(word)
    
    if ss["compound"] == 0.0: 
        summary_exsat["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary_exsat["positive"] +=1
    else:
        summary_exsat["negative"] +=1
        
print('exsat_comments',summary_exsat)

#find percentages of positivity, neutral and negativity

total_word_exsat = len(exsat_comments_tok)
pos_per_exsat = (summary_exsat['positive']/total_word_exsat)*100
neu_per_exsat = (summary_exsat['neutral']/total_word_exsat)*100
neg_per_exsat = (summary_exsat['negative']/total_word_exsat)*100

labels = 'Positive', 'Neutral', 'Negative'
sizes = [pos_per_exsat, neu_per_exsat, neg_per_exsat]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Extremely Satisfied Comments')

plt.show()


summary_somsat = {"positive":0,"neutral":0,"negative":0}

for word in somsat_comments_tok: 
    ss = sid.polarity_scores(word)
    
    if ss["compound"] == 0.0: 
        summary_somsat["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary_somsat["positive"] +=1
    else:
        summary_somsat["negative"] +=1
        
print('somsat_comments',summary_somsat)

#find percentages of positivity, neutral and negativity

total_word_somsat = len(somsat_comments_tok)
pos_per_somsat = (summary_somsat['positive']/total_word_somsat)*100
neu_per_somsat = (summary_somsat['neutral']/total_word_somsat)*100
neg_per_somsat = (summary_somsat['negative']/total_word_somsat)*100

labels = 'Positive', 'Neutral', 'Negative'
sizes = [pos_per_somsat, neu_per_somsat, neg_per_somsat]

fig2, ax2 = plt.subplots()
ax2.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Somewhat Satisfied Comments')

plt.show()


summary_exdis = {"positive":0,"neutral":0,"negative":0}

for word in exdis_comments_tok: 
    ss = sid.polarity_scores(word)
    
    if ss["compound"] == 0.0: 
        summary_exdis["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary_exdis["positive"] +=1
    else:
        summary_exdis["negative"] +=1
        
print('exdis_comments',summary_exdis)

#find percentages of positivity, neutral and negativity

total_word_exdis = len(exdis_comments_tok)
pos_per_exdis = (summary_exdis['positive']/total_word_exdis)*100
neu_per_exdis = (summary_exdis['neutral']/total_word_exdis)*100
neg_per_exdis = (summary_exdis['negative']/total_word_exdis)*100

labels = 'Positive', 'Neutral', 'Negative'
sizes = [pos_per_exdis, neu_per_exdis, neg_per_exdis]

fig3, ax3 = plt.subplots()
ax3.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Extremely Dissatisfied Comments')

plt.show()


summary_neu = {"positive":0,"neutral":0,"negative":0}

for word in neu_comments_tok: 
    ss = sid.polarity_scores(word)
    
    if ss["compound"] == 0.0: 
        summary_neu["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary_neu["positive"] +=1
    else:
        summary_neu["negative"] +=1
        
print('neu_comments',summary_neu)

#find percentages of positivity, neutral and negativity

total_word_neu = len(neu_comments_tok)
pos_per_neu = (summary_neu['positive']/total_word_neu)*100
neu_per_neu = (summary_neu['neutral']/total_word_neu)*100
neg_per_neu = (summary_neu['negative']/total_word_neu)*100

labels = 'Positive', 'Neutral', 'Negative'
sizes = [pos_per_neu, neu_per_neu, neg_per_neu]

fig4, ax4 = plt.subplots()
ax4.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax4.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Neither Satisfied Nor Dissatisfied Comments')

plt.show()
# Out:
# exsat_comments {'positive': 30, 'neutral': 381, 'negative': 4}
# somsat_comments {'positive': 12, 'neutral': 347, 'negative': 10}
# exdis_comments {'positive': 11, 'neutral': 310, 'negative': 3}
# neu_comments {'positive': 0, 'neutral': 2, 'negative': 1}

# %%
#word frequency and distribution

from nltk import *

fdist_exsat = FreqDist(exsat_comments_tok)
#print('exsat',fdist_exsat.most_common(10))

fdist_somsat = FreqDist(somsat_comments_tok)
print('somsat',fdist_somsat.most_common(10))

fdist_exdis = FreqDist(exdis_comments_tok)
print('exdis',fdist_exdis.most_common(10))

fdist_neu = FreqDist(neu_comments_tok)
print('neu',fdist_neu.most_common(10))
# Out:
# somsat [('the', 15), ('to', 12), ('I', 12), ('it', 10), ('and', 10), ('is', 8), ('a', 8), ('would', 6), ('of', 6), ('bike', 5)]
# exdis [('the', 19), ('to', 16), ('I', 15), ('a', 11), ('bike', 7), ('it', 6), ('on', 6), ('and', 6), ('that', 6), ('had', 5)]
# neu [('No', 1), ('throttle', 1), ('heavy', 1)]
